# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

from noggin import create_plot
plotter, fig, ax = create_plot(["loss", "accuracy"]) # <COGLINE>
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import Database
from Model import Autoencoder
from Model import train_model
from Model import save_model
from Model import load_model
database = Database.load_database("database.pkl")
# model = Autoencoder(D_full=512, D_hidden=200)
model = load_model("model.pkl")

train_model(model, database, plotter=plotter)
# Out:
# Loading Database
# Done!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 10>()
#       7 model = Autoencoder(D_full=512, D_hidden=200)
#       8 # model = load_model("model.pkl")
# ---> 10 train_model(model, database, plotter=plotter)
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Model.py:61, in train_model(model, database, batches, batch_size, epochs, optim, learning_rate, plotter)
#      59 for _ in range(epochs):
#      60     for _ in range(batch_size):
# ---> 61         triplets = database.get_training_batch(batch_size)
#      62         # triplets = master
#      63         caption_embeds, trues_embeds, confusers_embeds = unzip(triplets)
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:80, in Database.get_training_batch(self, batch_size)
#      79 def get_training_batch(self, batch_size: int):
# ---> 80     return [self.get_training_element() for _ in range(batch_size)]
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:80, in <listcomp>(.0)
#      79 def get_training_batch(self, batch_size: int):
# ---> 80     return [self.get_training_element() for _ in range(batch_size)]
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:84, in Database.get_training_element(self)
#      82 def get_training_element(self):
#      83     true_image_id = self.get_random_image_id()
# ---> 84     confuser_image_id = self.get_random_image_id()
#      85     true_caption_id = random.choice(self.image_data[true_image_id][1])
#      86     return self.caption_embeddings[true_caption_id], self.resnet18_features[true_image_id].flatten(), self.resnet18_features[confuser_image_id].flatten()
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:89, in Database.get_random_image_id(self)
#      88 def get_random_image_id(self):
# ---> 89     return random.choice(list(self.image_data.keys()))
#
# File ~\.conda\envs\week3\lib\random.py:287, in Random.choice(self, seq)
#     285 def choice(self, seq):
#     286     """Choose a random element from a non-empty sequence."""
# --> 287     try:
#     288         i = self._randbelow(len(seq))
#     289     except ValueError:
#
# KeyboardInterrupt:

# %%
save_model(model, "model.pkl")
# Out:
# Saving Model
# Done!

# %%
Database.save_database(database, "database.pkl")
