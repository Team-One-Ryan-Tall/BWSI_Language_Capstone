# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

from noggin import create_plot
plotter, fig, ax = create_plot(["loss", "accuracy"]) # <COGLINE>
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import Database
from Model import Autoencoder
from Model import train_model
from Model import save_model
from Model import load_model
database = Database.load_database("database.pkl")
# model = Autoencoder(D_full=512, D_hidden=200)
model = load_model("model.pkl")
train_model(model, database, plotter=plotter)
# Out:
# Loading Database
# Done!
# Loading Model
# Done!
# 0.13243451714515686 0.90625
# 0.11580051026441357 0.96875
# 0.12958496489413657 0.8125
# 0.13923487067222595 0.90625
# 0.1297795443807675 0.84375
# 0.12176664173603058 0.9375
# 0.14477144181728363 0.875
# 0.15091682970523834 0.78125
# 0.1699078772601595 0.6875
# 0.1269982494294863 0.875
# 0.11820686608552933 0.875
# 0.12852458655834198 0.96875
# 0.10686725142764941 0.9375
# 0.1406990866928587 0.84375
# 0.1512051820755005 0.78125
# 0.1378176361322403 0.84375
# 0.12696660663223044 0.8125
# 0.09736727632515571 0.875
# 0.12759263813495636 0.875
# 0.12181409230489118 0.875
# 0.11268522590398788 0.9375
# 0.16666503250598907 0.71875
# 0.13400326669216156 0.9375
# 0.1488778293132782 0.84375
# 0.1250472068786621 0.875
# 0.12797134347683592 0.84375
# 0.07886682450771332 0.9375
# 0.11214106529577686 0.875
# 0.12759652733802795 0.8125
# 0.12937402975561965 0.875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 9>()
#       7 # model = Autoencoder(D_full=512, D_hidden=200)
#       8 model = load_model("model.pkl")
# ----> 9 train_model(model, database, plotter=plotter)
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Model.py:61, in train_model(model, database, batches, batch_size, epochs, optim, learning_rate, plotter)
#      59 for _ in range(epochs):
#      60     for _ in range(batch_size):
# ---> 61         triplets = database.get_training_batch(batch_size)
#      62         # triplets = master
#      63         caption_embeds, trues_embeds, confusers_embeds = unzip(triplets)
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:80, in get_training_batch(self, batch_size)
#      77     caption_id =  random.choice(list(self.caption_data.keys()))
#      78     return (caption_id, self.caption_data[caption_id][1])
# ---> 80 def get_features(self, image_id: int):
#      81     return self.resnet18_features[image_id]
#      83 def get_training_batch(self, batch_size: int):
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:80, in <listcomp>(.0)
#      77     caption_id =  random.choice(list(self.caption_data.keys()))
#      78     return (caption_id, self.caption_data[caption_id][1])
# ---> 80 def get_features(self, image_id: int):
#      81     return self.resnet18_features[image_id]
#      83 def get_training_batch(self, batch_size: int):
#
# File ~\Desktop\Projects\Programming\Python\BWSI\Week3\BWSI_Language_Capstone\Database.py:86, in get_training_element(self)
#      83 def get_training_batch(self, batch_size: int):
#      84     return [self.get_training_element() for _ in range(batch_size)]
# ---> 86 def get_training_element(self):
#      87     true_image_id = self.get_random_image_id()
#      88     confuser_image_id = self.get_random_image_id()
#
# KeyboardInterrupt:

# %%
save_model(model, "model.pkl")
# Out:
# Saving Model
# Done!

# %%
Database.save_database(database, "database.pkl")
